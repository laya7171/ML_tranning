# %%
import numpy as  np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Copy of Customer Call List.xlsx")

# %%
df.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter    /White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    Not_Useful_Column
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# First_Name           0
# Last_Name            1
# Phone_Number         2
# Address              0
# Paying Customer      0
# Do_Not_Contact       4
# Not_Useful_Column    0
# dtype: int64

# %%
df = df.drop(["Not_Useful_Column"],axis = 1)

# %%
df.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter    /White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No

# %%
df.drop_duplicates()
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.replace("N/a","")
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID         0
# First_Name         0
# Last_Name          1
# Phone_Number       2
# Address            0
# Paying Customer    0
# Do_Not_Contact     4
# dtype: int64

# %%
df["Last_Name"] = df["Last_Name"].str.replace(r'^[^\w]', '', regex=True)

# %%
df.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter     White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No

# %%
df["Phone_Number"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 21 entries, 0 to 20
# Series name: Phone_Number
# Non-Null Count  Dtype
# --------------  -----
# 19 non-null     object
# dtypes: object(1)
# memory usage: 300.0+ bytes

# %%
df["Phone_Number"] = df['Phone_Number'].astype(str).str.replace(r'\D', '', regex=True)

# %%
df.head()
# Out:
#    CustomerID First_Name Last_Name Phone_Number  \
# 0        1001      Frodo   Baggins   1235455421
# 1        1002       Abed     Nadir   1236439775
# 2        1003     Walter     White   7066950392
# 3        1004     Dwight   Schrute   1235432345
# 4        1005        Jon      Snow   8766783469
#
#                                  Address Paying Customer Do_Not_Contact
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No

# %%
df["Phone_Number"] = df['Phone_Number'].astype(str).str[:3]+ '-' + df['Phone_Number'].astype(str).str[3:6] +'-'+ df['Phone_Number'].astype(str).str[6:9]

# %%
df.drop(["Phone_Number"],axis = 1)
# Out:
#     CustomerID First_Name    Last_Name                                Address  \
# 0         1001      Frodo      Baggins                  123 Shire Lane, Shire
# 1         1002       Abed        Nadir                    93 West Main Street
# 2         1003     Walter        White                     298 Drugs Driveway
# 3         1004     Dwight      Schrute  980 Paper Avenue, Pennsylvania, 18503
# 4         1005        Jon         Snow                       123 Dragons Road
# 5         1006        Ron      Swanson                       768 City Parkway
# 6         1007       Jeff       Winger                      1209 South Street
# 7         1008   Sherlock       Holmes                          98 Clue Drive
# 8         1009    Gandalf          NaN                       123 Middle Earth
# 9         1010      Peter       Parker             25th Main Street, New York
# 10        1011    Samwise       Gamgee                  612 Shire Lane, Shire
# ...

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# CustomerID         0
# First_Name         0
# Last_Name          0
# Phone_Number       0
# Address            0
# Paying Customer    0
# Do_Not_Contact     0
# dtype: int64

# %%
df.head()
# Out:
#    CustomerID First_Name Last_Name Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-542
# 1        1002       Abed     Nadir  123-643-977
# 3        1004     Dwight   Schrute  123-543-234
# 4        1005        Jon      Snow  876-678-346
# 5        1006        Ron   Swanson  304-762-246
#
#                                  Address Paying Customer Do_Not_Contact
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
# 5                       768 City Parkway             Yes            Yes

# %%
df[["zip_code", "street"]] = df["Address"].str.split(',', n=1, expand=True)

# %%
df.head()
# Out:
#    CustomerID First_Name Last_Name Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-542
# 1        1002       Abed     Nadir  123-643-977
# 3        1004     Dwight   Schrute  123-543-234
# 4        1005        Jon      Snow  876-678-346
# 5        1006        Ron   Swanson  304-762-246
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
# 5                       768 City Parkway             Yes            Yes
#
#               zip_code                street
# 0       123 Shire Lane                 Shire
# 1  93 West Main Street                  None
# 3     980 Paper Avenue   Pennsylvania, 18503
# 4     123 Dragons Road                  None
# ...

# %%
df
# Out:
#     CustomerID First_Name    Last_Name Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-542
# 1         1002       Abed        Nadir  123-643-977
# 3         1004     Dwight      Schrute  123-543-234
# 4         1005        Jon         Snow  876-678-346
# 5         1006        Ron      Swanson  304-762-246
# 6         1007       Jeff       Winger           --
# 7         1008   Sherlock       Holmes  876-678-346
# 9         1010      Peter       Parker  123-545-542
# 10        1011    Samwise       Gamgee           --
# 12        1013        Don       Draper  123-543-234
# 13        1014     Leslie        Knope  876-678-346
# 14        1015       Toby  Flenderson_  304-762-246
# 15        1016        Ron      Weasley  123-545-542
# 16        1017   Michael         Scott  123-643-977
# 18        1019      Creed       Braton           --
# 19        1020     Anakin    Skywalker  876-678-346
# 20        1020     Anakin    Skywalker  876-678-346
#
# ...

# %%
df["Phone_Number"] = df["Phone_Number"].str.replace("--"," ")

# %%
df
# Out:
#     CustomerID First_Name    Last_Name Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-542
# 1         1002       Abed        Nadir  123-643-977
# 3         1004     Dwight      Schrute  123-543-234
# 4         1005        Jon         Snow  876-678-346
# 5         1006        Ron      Swanson  304-762-246
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes  876-678-346
# 9         1010      Peter       Parker  123-545-542
# 10        1011    Samwise       Gamgee
# 12        1013        Don       Draper  123-543-234
# 13        1014     Leslie        Knope  876-678-346
# 14        1015       Toby  Flenderson_  304-762-246
# 15        1016        Ron      Weasley  123-545-542
# 16        1017   Michael         Scott  123-643-977
# 18        1019      Creed       Braton
# 19        1020     Anakin    Skywalker  876-678-346
# 20        1020     Anakin    Skywalker  876-678-346
#
# ...

# %%
df['Zip_Code'] = df['zip_code'].astype(str).str.extract(r'(\d+)', expand=False)

# %%
df['Street_Address'] = df['zip_code'].astype(str).str.extract(r'([A-Za-z]+)', expand=False)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-542
# 1         1002       Abed        Nadir  123-643-977
# 3         1004     Dwight      Schrute  123-543-234
# 4         1005        Jon         Snow  876-678-346
# 5         1006        Ron      Swanson  304-762-246
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes  876-678-346
# 9         1010      Peter       Parker  123-545-542
# 10        1011    Samwise       Gamgee
# 12        1013        Don       Draper  123-543-234
# 13        1014     Leslie        Knope  876-678-346
# 14        1015       Toby  Flenderson_  304-762-246
# 15        1016        Ron      Weasley  123-545-542
# 16        1017   Michael         Scott  123-643-977
# 18        1019      Creed       Braton
# 19        1020     Anakin    Skywalker  876-678-346
# 20        1020     Anakin    Skywalker  876-678-346
#
# ...

# %%
df.drop(["Address","zip_code","Phone_Number"],axis = 1)
# Out:
#     CustomerID First_Name    Last_Name Paying Customer Do_Not_Contact  \
# 0         1001      Frodo      Baggins             Yes             No
# 1         1002       Abed        Nadir              No            Yes
# 3         1004     Dwight      Schrute             Yes              Y
# 4         1005        Jon         Snow               Y             No
# 5         1006        Ron      Swanson             Yes            Yes
# 6         1007       Jeff       Winger              No             No
# 7         1008   Sherlock       Holmes               N             No
# 9         1010      Peter       Parker             Yes             No
# 10        1011    Samwise       Gamgee             Yes             No
# 12        1013        Don       Draper             Yes              N
# 13        1014     Leslie        Knope             Yes             No
# 14        1015       Toby  Flenderson_               N             No
# ...

# %%
df = df.fillna("")

# %%
df
# Out:
#     CustomerID First_Name    Last_Name Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-542
# 1         1002       Abed        Nadir  123-643-977
# 3         1004     Dwight      Schrute  123-543-234
# 4         1005        Jon         Snow  876-678-346
# 5         1006        Ron      Swanson  304-762-246
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes  876-678-346
# 9         1010      Peter       Parker  123-545-542
# 10        1011    Samwise       Gamgee
# 12        1013        Don       Draper  123-543-234
# 13        1014     Leslie        Knope  876-678-346
# 14        1015       Toby  Flenderson_  304-762-246
# 15        1016        Ron      Weasley  123-545-542
# 16        1017   Michael         Scott  123-643-977
# 18        1019      Creed       Braton
# 19        1020     Anakin    Skywalker  876-678-346
# 20        1020     Anakin    Skywalker  876-678-346
#
# ...

# %%
df['Stree_Address'] = df['zip_code'].astype(str).str.extract(r'([A-Za-z ]+)', expand=False)

# %%
df.drop(["street","Street_Address","zip_code","Phone_number","Address"],axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-cf89acaf9922> in <cell line: 0>()
# ----> 1 df.drop(["street","Street_Address","zip_code","Phone_number","Address"],axis = 1)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df.isnull().sum()

# %%
df
