# %% [markdown]
# <a href="https://colab.research.google.com/github/Nishchal-ll/Machine-Learning/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Pandas 🐼🐼
# 👉👉Data preprocessing in Machine Learning using Pandas👈👈
#
# Data preprocessing is required tasks for cleaning the data and making it suitable for a machine learning model which also increases the accuracy and efficeincy of a machine learning model.
#
# 🐼👉Pandas is an open source Python package that is most widely used for data science/data analysis and machine learning tasks. It is built on top of another package name Numpy, which provides support for multi dimensional arrays. Preprocessing is the process of doing pre-analysis of data,in order to transofrm them into a standard and normalized format.
#
# Preprocessing involves trhe following aspects:👇👇
#
#
# *   missing values
# *   data standarization
# *   data normalization
# *   data binning

# %%
import pandas as pd

data={
    "cars": ["bmw","honda","suzuki"],
    "models": ["2007","2014","2021"],
    "passenger" :["4","5","6"]
}
data
# Out:
# {'cars': ['bmw', 'honda', 'suzuki'],
#  'models': ['2007', '2014', '2021'],
#  'passenger': ['4', '5', '6']}

# %%
df = pd.DataFrame(data)
df
# Out:
#      cars models passenger
# 0     bmw   2007         4
# 1   honda   2014         5
# 2  suzuki   2021         6

# %%
df.to_csv("/content/drive/MyDrive/car_data.csv")

# %%
data={
    "calories": ["420","500","390"],
    "duration": ["50","60","45"],
}
data
# Out:
# {'calories': ['420', '500', '390'], 'duration': ['50', '60', '45']}

# %%
df = pd.DataFrame(data)
df
# Out:
#      cars models passenger
# 0     bmw   2007         4
# 1   honda   2014         5
# 2  suzuki   2021         6

# %%
print(df.loc[1])
# Out:
# cars         honda
# models        2014
# passenger        5
# Name: 1, dtype: object

# %%
print(df.loc[[0,1]])
# Out:
#     cars models passenger
# 0    bmw   2007         4
# 1  honda   2014         5

# %%
newdata={
    "calories":[100,200,300,400],
    "duration":[20,30,40,50]
}
newdata
# Out:
# {'calories': [100, 200, 300, 400], 'duration': [20, 30, 40, 50]}

# %%
df=pd.DataFrame(newdata)
df
# Out:
#   calories duration
# 0      100       20
# 1      200       30
# 2      300       40
# 3      400       50

# %%
df=pd.DataFrame(data, index = ["days1","day2","day3"])
df
# Out:
#          cars models passenger
# days1     bmw   2007         4
# day2    honda   2014         5
# day3   suzuki   2021         6

# %%
print(df.loc[["days1","day2"]])
# Out:
#         cars models passenger
# days1    bmw   2007         4
# day2   honda   2014         5

# %% [markdown]
# ## Data Cleaning with Pandas ##
#
# Bad data can be
#
# *   empty cells
# *   wrong data
# *   duplicates

# %%
import pandas as pd
df=pd.read_csv("")
df.tail(5)
# Out:
#     Duration  Date        Pulse  Maxpulse  Calories  Unnamed: 5
# 27        27    60  2020/12/27'        92       118       241.0
# 28        28    60  2020/12/28'       103       132         NaN
# 29        29    60  2020/12/29'       100       132       280.0
# 30        30    60  2020/12/30'       102       129       380.3
# 31        31    60  2020/12/31'        92       115       243.0

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/pandas_dataset.csv")
df.tail(5)
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 27        60  2020/12/27'     92       118     241.0
# 28        60  2020/12/28'    103       132       NaN
# 29        60  2020/12/29'    100       132     280.0
# 30        60  2020/12/30'    102       129     380.3
# 31        60  2020/12/31'     92       115     243.0

# %%
df["Date"] = df["Date"].replace("'","", regex=True)
df.tail(5)
# Out:
#     Duration  Date  Pulse  Maxpulse  Calories
# 27        60  1227     92       118     241.0
# 28        60  1228    103       132       NaN
# 29        60  1229    100       132     280.0
# 30        60  1230    102       129     380.3
# 31        60  1231     92       115     243.0

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/pandas_dataset.csv")
df.tail(5)
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 27        60  2020/12/27'     92       118     241.0
# 28        60  2020/12/28'    103       132       NaN
# 29        60  2020/12/29'    100       132     280.0
# 30        60  2020/12/30'    102       129     380.3
# 31        60  2020/12/31'     92       115     243.0

# %%
df["Date"] = df["Date"].replace("'","", regex=True)
df.tail(5)
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 27        60  2020/12/27     92       118     241.0
# 28        60  2020/12/28    103       132       NaN
# 29        60  2020/12/29    100       132     280.0
# 30        60  2020/12/30    102       129     380.3
# 31        60  2020/12/31     92       115     243.0

# %%
#return a dataset with no empty cells
# df.dropna() will remove empty cells but will not change the dataframe
# if we want data frame to be changed use implace=true

new_df= df.dropna()
new_df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
#another way of handling the null values is by replacing null value with some value

df_new2= df.fillna("nishchal")
df_new2
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
# fill specific columns null value by  specific values

df["Calories"].fillna(1500, inplace=True)
df
# Out:
# <ipython-input-54-a68f2f202662>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Calories"].fillna(1500, inplace=True)
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# ...

# %%
new_df=df.dropna()
new_df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
# fill null values with mean median and mode

import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/pandas_dataset.csv")
x=df["Calories"].mean()
df["Calories"].fillna(x, inplace= True)
df=df.dropna()
df["Date"] = df["Date"].replace("'","", regex=True)
df
# Out:
# <ipython-input-58-12946e06241f>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Calories"].fillna(x, inplace= True)
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130    409.10
# 1         60  2020/12/02    117       145    479.00
# 2         60  2020/12/03    103       135    340.00
# 3         45  2020/12/04    109       175    282.40
# 4         45  2020/12/05    117       148    406.00
# 5         60  2020/12/06    102       127    300.00
# ...

# %%
## df.innull()-----null check garna
## isnull.sum()----total null nikalna

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/world_population.csv")
data=df

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/countries of the world.txt")
df
# Out:
#                                        Country\tRegion
# 0          Afghanistan \tASIA (EX. NEAR EAST)
# 1        Albania \tEASTERN EUROPE
# 2        Algeria \tNORTHERN AFRICA
# 3    American Samoa \tOCEANIA                      ...
# 4        Andorra \tWESTERN EUROPE
# ..                                                 ...
# 222    West Bank \tNEAR EAST
# 223  Western Sahara \tNORTHERN AFRICA              ...
# 224        Yemen \tNEAR EAST
# 225       Zambia \tSUB-SAHARAN AFRICA
# 226     Zimbabwe \tSUB-SAHARAN AFRICA
#
# [227 rows x 1 columns]

# %%
import pandas as pd
df=pd.read_table("/content/drive/MyDrive/Colab Notebooks/countries of the world.txt")
df
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
import pandas as pd
df=pd.read_json("/content/drive/MyDrive/Colab Notebooks/json_sample.json")
df
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# ...

# %%
import pandas as pd
df=pd.read_excel("/content/drive/MyDrive/Colab Notebooks/world_population_excel_workbook.xlsx", sheet_name="Sheet1")
df
# Out:
#      Rank CCA3            Country           Capital
# 0      36  AFG        Afghanistan             Kabul
# 1     138  ALB            Albania            Tirana
# 2      34  DZA            Algeria           Algiers
# 3     213  ASM     American Samoa         Pago Pago
# 4     203  AND            Andorra  Andorra la Vella
# ..    ...  ...                ...               ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu
# 230   172  ESH     Western Sahara         El AaiÃºn
# 231    46  YEM              Yemen             Sanaa
# 232    63  ZMB             Zambia            Lusaka
# 233    74  ZWE           Zimbabwe            Harare
#
# [234 rows x 4 columns]

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/world_population.csv")
filtered_data=df[df['Rank'] <= 10]
output=filtered_data.sort_values(by="Rank")
display(output)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41      1.425887e+09     1.424930e+09     1.393715e+09     1.348191e+09
# 92      1.417173e+09     1.396387e+09     1.322867e+09     1.240614e+09
# ...

# %%
# filtered_country=df[df['Country'] == 'Brazil']
# filtered_countryy=df[df['Country'] == 'Bangladesh']
# display(filtered_countryy,filtered_country)

## isin method use garne fetch garna
filtered_country= df[df['Country'].isin(['Bangladesh','Brazil'])]
# list_items=list(filtered_country)
# display(list_items)
filtered_country
# Out:
#     Rank CCA3     Country   Capital      Continent  2022 Population  \
# 16     8  BGD  Bangladesh     Dhaka           Asia      171186372.0
# 27     7  BRA      Brazil  Brasilia  South America      215313498.0
#
#     2020 Population  2015 Population  2010 Population  2000 Population  \
# 16      167420951.0      157830000.0      148391139.0      129193327.0
# 27      213196304.0      205188205.0      196353492.0      175873720.0
#
#     1990 Population  1980 Population  1970 Population  Area (km²)  \
# 16      107147651.0       83929765.0       67541860.0    147570.0
# 27      150706446.0      122288383.0       96369875.0   8515767.0
#
#     Density (per km²)  Growth Rate  World Population Percentage
# 16          1160.0350       1.0108                         2.15
# 27            25.2841       1.0046                         2.70

# %%
# filtered_name= df[df['Country'].str.isin(['United'])]
filtered_name=df[df.Country.str.contains('United')]
filtered_name
# Out:
#      Rank CCA3                       Country           Capital      Continent  \
# 219    97  ARE          United Arab Emirates         Abu Dhabi           Asia
# 220    21  GBR                United Kingdom            London         Europe
# 221     3  USA                 United States  Washington, D.C.  North America
# 222   200  VIR  United States Virgin Islands  Charlotte Amalie  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 219        9441129.0        9287289.0        8916899.0        8481771.0
# 220       67508936.0       67059474.0       65224364.0       62760039.0
# 221      338289857.0      335942003.0      324607776.0      311182845.0
# 222          99465.0         100442.0         102803.0         106142.0
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 219        3275333.0        1900151.0        1014048.0         298084.0
# ...

# %%
df2=df
df2= df2.set_index('Country')
display(df2)
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
# ...

# %%
df[['Continent', 'CCA3']]
# Out:
#     Continent CCA3
# 0        Asia  AFG
# 1      Europe  ALB
# 2      Africa  DZA
# 3     Oceania  ASM
# 4      Europe  AND
# ..        ...  ...
# 229   Oceania  WLF
# 230    Africa  ESH
# 231      Asia  YEM
# 232    Africa  ZMB
# 233    Africa  ZWE
#
# [234 rows x 2 columns]

# %%
df[df["Country"]=="Zimbabwe"]
# Out:
#      Rank CCA3   Country Capital Continent  2022 Population  2020 Population  \
# 233    74  ZWE  Zimbabwe  Harare    Africa       16320537.0       15669666.0
#
#      2015 Population  2010 Population  2000 Population  1990 Population  \
# 233       14154937.0       12839771.0       11834676.0       10113893.0
#
#      1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# 233        7049926.0        5202918.0    390757.0            41.7665
#
#      Growth Rate  World Population Percentage
# 233       1.0204                          0.2

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Continent', 'Country')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-b153697961ce> in <cell line: 0>()
# ----> 1 df["Continent","Country"]
#
# ...
